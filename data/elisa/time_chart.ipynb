# %%
import openpyxl
import pandas as pd
import numpy as np

# %%
# Load the Excel file
file_path = '../data/gold-medal-times.xlsx'

# Load the 'Data' worksheet
data = pd.read_excel(file_path, sheet_name='Data', usecols='B:D')

# Rename columns
data = data.rename(columns={'Unnamed: 1': 'Year','Unnamed: 2': 'Men', 'Unnamed: 3': 'Women'})

# Convert the columns to numeric, ignoring non-numeric values
data['Men'] = pd.to_numeric(data['Men'], errors='coerce')
data['Women'] = pd.to_numeric(data['Women'], errors='coerce')

print(data.head(25))
# Out:
#                                                  Year     Men   Women
# 0                                                 NaN     NaN     NaN
# 1   Gold medal times in the 1,500m at the Summer O...     NaN     NaN
# 2   Gold medal winning times in the Men's and Wome...     NaN     NaN
# 3                                                 NaN     NaN     NaN
# 4                                         Athens 1896  273.20     NaN
# 5                                          Paris 1900  246.20     NaN
# 6                                      St. Louis 1904  245.40     NaN
# 7                                         London 1908  243.40     NaN
# 8                                      Stockholm 1912  236.80     NaN
# 9                                        Antwerp 1920  241.80     NaN
# 10                                         Paris 1924  233.60     NaN
# 11                                     Amsterdam 1928  233.20     NaN
# 12                                   Los Angeles 1932  231.20     NaN
# 13                                        Berlin 1936  227.80     NaN
# 14                                        London 1948  229.80     NaN
# 15                                      Helsinki 1952  225.20     NaN
# 16                                     Melbourne 1956  221.20     NaN
# 17                                          Rome 1960  215.60     NaN
# 18                                         Tokyo 1964  218.10     NaN
# 19                                   Mexico City 1968  214.90     NaN
# 20                                        Munich 1972  216.33  241.38
# 21                                      Montreal 1976  219.17  245.48
# 22                                        Moscow 1980  218.40  236.60
# 23                                   Los Angeles 1984  212.53  243.25
# 24                                         Seoul 1988  215.96  233.96

# %%
def convert_to_minutes_seconds(time_in_seconds):
    minutes = int(time_in_seconds // 60)
    seconds = time_in_seconds % 60
    return f"{minutes}:{seconds:.2f}"

# Calculate nanmax and nanmin of columns
max_value_men = convert_to_minutes_seconds(np.nanmax(data['Men']))
min_value_men = convert_to_minutes_seconds(np.nanmin(data['Men']))
max_value_women = convert_to_minutes_seconds(np.nanmax(data['Women']))
min_value_women = convert_to_minutes_seconds(np.nanmin(data['Women']))

print("Slowest Winning Time Men:", max_value_men)
print("Fastest Winning Time Men:", min_value_men)
print("Slowest Winning Time Women:", max_value_women)
print("Fastest Winning Time Women:", min_value_women)
# Out:
# Slowest Winning Time Men: 4:33.20
# Fastest Winning Time Men: 3:28.32
# Slowest Winning Time Women: 4:10.74
# Fastest Winning Time Women: 3:53.11

# %%
# Load the Excel file
file_path = '../data/medals-per-country.xlsx'

# Load the 'Data' worksheet
data = pd.read_excel(file_path, sheet_name='Data', usecols='B:E')

# Rename columns
data = data.rename(columns={'Unnamed: 1': 'Country','Unnamed: 2': 'Gold', 'Unnamed: 3': 'Silver', 'Unnamed: 4': 'Bronze'})

# Convert the columns to numeric, ignoring non-numeric values
data['Gold'] = pd.to_numeric(data['Gold'], errors='coerce')
data['Silver'] = pd.to_numeric(data['Silver'], errors='coerce')
data['Bronze'] = pd.to_numeric(data['Bronze'], errors='coerce')

# Print the first few lines of the 'Data' worksheet
print(data.head(10))

# Find the country with the most gold, silver, and bronze medals
most_gold_country = data.loc[data['Gold'].idxmax()]['Country']
most_silver_country = data.loc[data['Silver'].idxmax()]['Country']
most_bronze_country = data.loc[data['Bronze'].idxmax()]['Country']

# Get the count of medals for each country
most_gold_count = int(data['Gold'].max())
most_silver_count = int(data['Silver'].max())
most_bronze_count = int(data['Bronze'].max())

print("Country with the most gold medals:", most_gold_country, "with", most_gold_count, "gold medals")
print("Country with the most silver medals:", most_silver_country, "with", most_silver_count, "silver medals")
print("Country with the most bronze medals:", most_bronze_country, "with", most_bronze_count, "bronze medals")
# Out:
#                                              Country  Gold  Silver  Bronze
# 0                                                NaN   NaN     NaN     NaN
# 1  Medal count by country in the Men's 1,500m at ...   NaN     NaN     NaN
# 2  Medal count by country in the Men's 1,500m at ...   NaN     NaN     NaN
# 3                                                NaN   NaN     NaN     NaN
# 4                                      Great Britain   5.0     5.0     4.0
# 5                                              Kenya   4.0     3.0     2.0
# 6                                      United States   3.0     7.0     4.0
# 7                                        New Zealand   3.0     1.0     3.0
# 8                                            Finland   3.0     NaN     1.0
# 9                                            Algeria   2.0     1.0     NaN
# Country with the most gold medals: Great Britain with 5 gold medals
# Country with the most silver medals: United States with 7 silver medals
# Country with the most bronze medals: Great Britain with 4 bronze medals

# %%
# Open results.json
import json
with open('./results.json', 'r') as file:
    track_results = json.load(file)

country_codes = { 'Great Britain': 'GBR', 'Kenya': 'KEN', 'United States': 'USA', 'New Zealand': 'NZL', 'Finland': 'FIN', 'Algeria': 'ALG', 'Australia': 'AUS', 'Morocco': 'MAR', 'Spain': 'ESP', 'Sweden': 'SWE', 'Italy': 'ITA', 'Ireland': 'IRL', 'Luxembourg': 'LUX', 'France': 'FRA' }
top_15_countries_men = ['GBR', 'KEN', 'USA', 'NZL', 'FIN', 'ALG', 'AUS', 'MAR', 'ESP', 'SWE', 'ITA', 'IRL', 'LUX', 'FRA']
top_15_countries_women = []

track_results_men = []
track_results_women = []

for games in track_results:
    if games['name'] == '1500M Men':
        for result in games['games']:
            for stats in result['results']:
                if stats['nationality'] in top_15_countries_men:
                    track_results_men.append({
                        'year': result['year'],
                        'country': stats['nationality'],
                        'medal': stats['medal'],
                        'time': stats['result']
                    })
    elif games['name'] == '1500M Women':
        for result in games['games']:
            for stats in result['results']:
                track_results_women.append({
                    'year': result['year'],
                    'country': stats['nationality'],
                    'medal': stats['medal'],
                    'time': stats['result']
                })

print(track_results_women)
print(track_results_men)
# Out:
# [{'year': 2016, 'country': 'KEN', 'medal': 'G', 'time': '4:08.92'}, {'year': 2016, 'country': 'ETH', 'medal': 'S', 'time': '4:10.27'}, {'year': 2016, 'country': 'USA', 'medal': 'B', 'time': '4:10.53'}, {'year': 2008, 'country': 'KEN', 'medal': 'G', 'time': '4:00.23'}, {'year': 2008, 'country': 'UKR', 'medal': 'S', 'time': '4:01.63'}, {'year': 2008, 'country': 'UKR', 'medal': 'B', 'time': '4:01.78'}, {'year': 2000, 'country': 'ALG', 'medal': 'G', 'time': '04:05.10'}, {'year': 2000, 'country': 'ROU', 'medal': 'S', 'time': '04:05.15'}, {'year': 2000, 'country': 'ROU', 'medal': 'B', 'time': '04:05.27'}, {'year': 1992, 'country': 'ALG', 'medal': 'G', 'time': '3:55.30'}, {'year': 1992, 'country': 'EUN', 'medal': 'S', 'time': '3:56.91'}, {'year': 1992, 'country': 'CHN', 'medal': 'B', 'time': '3:57.08'}, {'year': 1984, 'country': 'ITA', 'medal': 'G', 'time': '4:03.25'}, {'year': 1984, 'country': 'ROU', 'medal': 'S', 'time': '4:03.76'}, {'year': 1984, 'country': 'ROU', 'medal': 'B', 'time': '4:04.15'}, {'year': 1976, 'country': 'URS', 'medal': 'G', 'time': '4:05.48'}, {'year': 1976, 'country': 'GDR', 'medal': 'S', 'time': '4:06.02'}, {'year': 1976, 'country': 'GDR', 'medal': 'B', 'time': '4:06.09'}, {'year': 2012, 'country': 'TUR', 'medal': 'S', 'time': '4:10.40'}, {'year': 2012, 'country': 'BRN', 'medal': 'B', 'time': '4:10.74'}, {'year': 2004, 'country': 'GBR', 'medal': 'G', 'time': '3:57.90'}, {'year': 2004, 'country': 'RUS', 'medal': 'S', 'time': '3:58.12'}, {'year': 2004, 'country': 'ROU', 'medal': 'B', 'time': '3:58.39'}, {'year': 1996, 'country': 'RUS', 'medal': 'G', 'time': '4:00.83'}, {'year': 1996, 'country': 'ROU', 'medal': 'S', 'time': '4:01.54'}, {'year': 1996, 'country': 'AUT', 'medal': 'B', 'time': '4:03.02'}, {'year': 1980, 'country': 'URS', 'medal': 'G', 'time': '3:56.6'}, {'year': 1980, 'country': 'GDR', 'medal': 'S', 'time': '3:57.8'}, {'year': 1980, 'country': 'URS', 'medal': 'B', 'time': '3:59.6'}, {'year': 1972, 'country': 'URS', 'medal': 'G', 'time': '4:01.38'}, {'year': 1972, 'country': 'GDR', 'medal': 'S', 'time': '4:02.83'}, {'year': 1972, 'country': 'ITA', 'medal': 'B', 'time': '4:02.85'}]
# [{'year': 2016, 'country': 'USA', 'medal': 'G', 'time': '3:50.00'}, {'year': 2016, 'country': 'ALG', 'medal': 'S', 'time': '3:50.11'}, {'year': 2016, 'country': 'NZL', 'medal': 'B', 'time': '3:50.24'}, {'year': 2008, 'country': 'KEN', 'medal': 'G', 'time': '3:33.11'}, {'year': 2008, 'country': 'NZL', 'medal': 'S', 'time': '3:34.16'}, {'year': 2008, 'country': 'FRA', 'medal': 'B', 'time': '3:34.21'}, {'year': 2000, 'country': 'KEN', 'medal': 'G', 'time': '03:32.07'}, {'year': 2000, 'country': 'MAR', 'medal': 'S', 'time': '03:32.32'}, {'year': 2000, 'country': 'KEN', 'medal': 'B', 'time': '03:32.44'}, {'year': 1992, 'country': 'ESP', 'medal': 'G', 'time': '3:40.12'}, {'year': 1992, 'country': 'MAR', 'medal': 'S', 'time': '3:40.62'}, {'year': 1984, 'country': 'GBR', 'medal': 'G', 'time': '3:32.53'}, {'year': 1984, 'country': 'GBR', 'medal': 'S', 'time': '3:33.40'}, {'year': 1984, 'country': 'ESP', 'medal': 'B', 'time': '3:34.30'}, {'year': 1976, 'country': 'NZL', 'medal': 'G', 'time': '3:39.17'}, {'year': 1968, 'country': 'KEN', 'medal': 'G', 'time': '3:34.9'}, {'year': 1968, 'country': 'USA', 'medal': 'S', 'time': '3:37.8'}, {'year': 1960, 'country': 'AUS', 'medal': 'G', 'time': '3:35.6'}, {'year': 1960, 'country': 'FRA', 'medal': 'S', 'time': '3:38.4'}, {'year': 1952, 'country': 'LUX', 'medal': 'G', 'time': '3:45.2'}, {'year': 1952, 'country': 'USA', 'medal': 'S', 'time': '3:45.2'}, {'year': 1936, 'country': 'NZL', 'medal': 'G', 'time': '3:47.8'}, {'year': 1936, 'country': 'USA', 'medal': 'S', 'time': '3:48.4'}, {'year': 1936, 'country': 'ITA', 'medal': 'B', 'time': '3:49.2'}, {'year': 1928, 'country': 'FIN', 'medal': 'G', 'time': '3:53.2'}, {'year': 1928, 'country': 'FRA', 'medal': 'S', 'time': '3:53.8'}, {'year': 1928, 'country': 'FIN', 'medal': 'B', 'time': '3:56.4'}, {'year': 1920, 'country': 'GBR', 'medal': 'G', 'time': '4:01.8'}, {'year': 1920, 'country': 'GBR', 'medal': 'S', 'time': '4:02.4'}, {'year': 1920, 'country': 'USA', 'medal': 'B', 'time': '4:03.1'}, {'year': 1908, 'country': 'USA', 'medal': 'G', 'time': '4:03.4'}, {'year': 1908, 'country': 'GBR', 'medal': 'S', 'time': '4:03.6'}, {'year': 1908, 'country': 'GBR', 'medal': 'B', 'time': '4:04.0'}, {'year': 1900, 'country': 'GBR', 'medal': 'G', 'time': '4:06.2'}, {'year': 1900, 'country': 'FRA', 'medal': 'S', 'time': '4:06.6'}, {'year': 1900, 'country': 'USA', 'medal': 'B', 'time': '4:07.2'}, {'year': 2012, 'country': 'ALG', 'medal': 'G', 'time': '3:34.08'}, {'year': 2012, 'country': 'USA', 'medal': 'S', 'time': '3:34.79'}, {'year': 2012, 'country': 'MAR', 'medal': 'B', 'time': '3:35.13'}, {'year': 2004, 'country': 'MAR', 'medal': 'G', 'time': '3:34.18'}, {'year': 2004, 'country': 'KEN', 'medal': 'S', 'time': '3:34.30'}, {'year': 1996, 'country': 'ALG', 'medal': 'G', 'time': '3:35.78'}, {'year': 1996, 'country': 'ESP', 'medal': 'S', 'time': '3:36.40'}, {'year': 1996, 'country': 'KEN', 'medal': 'B', 'time': '3:36.72'}, {'year': 1980, 'country': 'GBR', 'medal': 'G', 'time': '3:38.4'}, {'year': 1980, 'country': 'GBR', 'medal': 'B', 'time': '3:39.0'}, {'year': 1972, 'country': 'FIN', 'medal': 'G', 'time': '3:36.33'}, {'year': 1972, 'country': 'KEN', 'medal': 'S', 'time': '3:36.81'}, {'year': 1972, 'country': 'NZL', 'medal': 'B', 'time': '3:37.46'}, {'year': 1964, 'country': 'NZL', 'medal': 'G', 'time': '3:38.1'}, {'year': 1964, 'country': 'NZL', 'medal': 'B', 'time': '3:39.6'}, {'year': 1956, 'country': 'IRL', 'medal': 'G', 'time': '3:41.2'}, {'year': 1956, 'country': 'AUS', 'medal': 'B', 'time': '3:42.0'}, {'year': 1948, 'country': 'SWE', 'medal': 'G', 'time': '3:49.8'}, {'year': 1948, 'country': 'SWE', 'medal': 'S', 'time': '3:50.4'}, {'year': 1932, 'country': 'ITA', 'medal': 'G', 'time': '3:51.2'}, {'year': 1932, 'country': 'GBR', 'medal': 'S', 'time': '3:52.6'}, {'year': 1924, 'country': 'FIN', 'medal': 'G', 'time': '3:53.6'}, {'year': 1924, 'country': 'GBR', 'medal': 'B', 'time': '3:55.6'}, {'year': 1912, 'country': 'GBR', 'medal': 'G', 'time': '3:56.8'}, {'year': 1 ...

# %%
# adjust the data as a dataframe where the columns are the countries and the rows are the times for each year

track_df_men = pd.DataFrame(track_results_men)
track_df_men.sort_values(by=['year', 'time'], inplace=True)

track_df_women = pd.DataFrame(track_results_women)
track_df_women.sort_values(by=['year', 'time'], inplace=True)

# %%
# Save the sorted dataframes to a json file
track_df_men.to_json('./track_results_men.json', orient='records')
track_df_women.to_json('./track_results_women.json', orient='records')

# %%
def update_best_times(best_times, country_code, time):
    if time < best_times.get(country_code):
        print("Updating time for", country_code, "from", best_times.get(country_code), "to", time)
        best_times[country_code] = time
    return best_times


def update_medal_count(medal_count, country_code, medal_type, count):
    new_medals = medal_count[country_code].copy()
    new_medals[medal_type] += count
    new_medals['total'] += count
    medal_count[country_code] = new_medals
    return medal_count
            
def string_to_time(string):
    minutes, seconds = string.split(':')
    return int(minutes) * 60 + float(seconds)

# %%
graph_data_men = []
best_times = {}
medal_counts = {}

for step in track_results_men:
    if step['country'] not in best_times:
        best_times[step['country']] = 100000
    if step['country'] not in medal_counts:
        medal_counts[step['country']] = {'total': 0, 'G': 0, 'S': 0, 'B': 0}

new_best_times = best_times.copy()
new_medals = medal_counts.copy()

for i in range(1896, 2021, 4):
    for entry in track_results_men:
        if entry['year'] == i:
            print(entry['country'])
            print(entry['year'])
            print(i)
            if entry['time'] == None:
                continue
            seconds = string_to_time(entry['time'])
            best_times = new_best_times.copy()
            new_best_times = update_best_times(best_times, entry['country'], seconds)
            medal_counts = new_medals.copy()
            new_medals = update_medal_count(medal_counts, entry['country'], entry['medal'], 1)

    print(i)
    print(best_times)
    print(medal_counts)
    graph_data_men.append({
        'year': i,
        'best_times': best_times,
        'medal_counts': medal_counts
    })

# Save the best times and medal counts to a json file
with open('./graph_data_men.json', 'w') as file:
    json.dump(graph_data_men, file, indent=4)
# Out:
# AUS
# 1896
# 1896
# Updating time for AUS from 100000 to 273.2
# USA
# 1896
# 1896
# Updating time for USA from 100000 to 274.0
# FRA
# 1896
# 1896
# Updating time for FRA from 100000 to 276.0
# 1896
# {'USA': 274.0, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 276.0, 'MAR': 100000, 'ESP': 100000, 'GBR': 100000, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 100000, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# GBR
# 1900
# 1900
# Updating time for GBR from 100000 to 246.2
# FRA
# 1900
# 1900
# Updating time for FRA from 276.0 to 246.6
# USA
# 1900
# 1900
# Updating time for USA from 274.0 to 247.2
# 1900
# {'USA': 247.2, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 246.6, 'MAR': 100000, 'ESP': 100000, 'GBR': 246.2, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 100000, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# USA
# 1904
# 1904
# Updating time for USA from 247.2 to 245.4
# USA
# 1904
# 1904
# USA
# 1904
# 1904
# 1904
# {'USA': 245.4, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 246.6, 'MAR': 100000, 'ESP': 100000, 'GBR': 246.2, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 100000, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 4, 'G': 1, 'S': 2, 'B': 1}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# USA
# 1908
# 1908
# Updating time for USA from 245.4 to 243.4
# GBR
# 1908
# 1908
# Updating time for GBR from 246.2 to 243.6
# GBR
# 1908
# 1908
# 1908
# {'USA': 243.4, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 246.6, 'MAR': 100000, 'ESP': 100000, 'GBR': 243.6, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 100000, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 5, 'G': 2, 'S': 2, 'B': 1}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# GBR
# 1912
# 1912
# Updating time for GBR from 243.6 to 236.8
# USA
# 1912
# 1912
# Updating time for USA from 243.4 to 236.9
# USA
# 1912
# 1912
# 1912
# {'USA': 236.9, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 246.6, 'MAR': 100000, 'ESP': 100000, 'GBR': 236.8, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 100000, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 7, 'G': 2, 'S': 3, 'B': 2}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 4, 'G': 2, 'S': 1, 'B': 1}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1916
# {'USA': 236.9, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 246.6, 'MAR': 100000, 'ESP': 100000, 'GBR': 236.8, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 100000, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 7, 'G': 2, 'S': 3, 'B': 2}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 4, 'G': 2, 'S': 1, 'B': 1}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# GBR
# 1920
# 1920
# GBR
# 1920
# 1920
# USA
# 1920
# 1920
# 1920
# {'USA': 236.9, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 246.6, 'MAR': 100000, 'ESP': 100000, 'GBR': 236.8, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 100000, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 8, 'G': 2, 'S': 3, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 6, 'G': 3, 'S': 2, 'B': 1}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# FIN
# 1924
# 1924
# Updating time for FIN from 100000 to 233.6
# GBR
# 1924
# 1924
# Updating time for GBR from 236.8 to 235.6
# 1924
# {'USA': 236.9, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 246.6, 'MAR': 100000, 'ESP': 100000, 'GBR': 235.6, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 233.6, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 8, 'G': 2, 'S': 3, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 7, 'G': 3, 'S': 2, 'B': 2}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# FIN
# 1928
# 1928
# Updating time for FIN from 233.6 to 233.2
# FRA
# 1928
# 1928
# Updating time for FRA from 246.6 to 233.8
# FIN
# 1928
# 1928
# 1928
# {'USA': 236.9, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 233.8, 'MAR': 100000, 'ESP': 100000, 'GBR': 235.6, 'AUS': 273.2, 'LUX': 100000, 'ITA': 100000, 'FIN': 233.2, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 8, 'G': 2, 'S': 3, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 7, 'G': 3, 'S': 2, 'B': 2}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# ITA
# 1932
# 1932
# Updating time for ITA from 100000 to 231.2
# GBR
# 1932
# 1932
# Updating time for GBR from 235.6 to 232.6
# 1932
# {'USA': 236.9, 'ALG': 100000, 'NZL': 100000, 'KEN': 100000, 'FRA': 233.8, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 273.2, 'LUX': 100000, 'ITA': 231.2, 'FIN': 233.2, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 8, 'G': 2, 'S': 3, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# NZL
# 1936
# 1936
# Updating time for NZL from 100000 to 227.8
# USA
# 1936
# 1936
# Updating time for USA from 236.9 to 228.4
# ITA
# 1936
# 1936
# Updating time for ITA from 231.2 to 229.2
# 1936
# {'USA': 228.4, 'ALG': 100000, 'NZL': 227.8, 'KEN': 100000, 'FRA': 233.8, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 273.2, 'LUX': 100000, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 9, 'G': 2, 'S': 4, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1940
# {'USA': 228.4, 'ALG': 100000, 'NZL': 227.8, 'KEN': 100000, 'FRA': 233.8, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 273.2, 'LUX': 100000, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 9, 'G': 2, 'S': 4, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1944
# {'USA': 228.4, 'ALG': 100000, 'NZL': 227.8, 'KEN': 100000, 'FRA': 233.8, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 273.2, 'LUX': 100000, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 100000, 'SWE': 100000}
# {'USA': {'total': 9, 'G': 2, 'S': 4, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# SWE
# 1948
# 1948
# Updating time for SWE from 100000 to 229.8
# SWE
# 1948
# 1948
# 1948
# {'USA': 228.4, 'ALG': 100000, 'NZL': 227.8, 'KEN': 100000, 'FRA': 233.8, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 273.2, 'LUX': 100000, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 100000, 'SWE': 229.8}
# {'USA': {'total': 9, 'G': 2, 'S': 4, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# LUX
# 1952
# 1952
# Updating time for LUX from 100000 to 225.2
# USA
# 1952
# 1952
# Updating time for USA from 228.4 to 225.2
# 1952
# {'USA': 225.2, 'ALG': 100000, 'NZL': 227.8, 'KEN': 100000, 'FRA': 233.8, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 273.2, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 100000, 'SWE': 229.8}
# {'USA': {'total': 10, 'G': 2, 'S': 5, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# IRL
# 1956
# 1956
# Updating time for IRL from 100000 to 221.2
# AUS
# 1956
# 1956
# Updating time for AUS from 273.2 to 222.0
# 1956
# {'USA': 225.2, 'ALG': 100000, 'NZL': 227.8, 'KEN': 100000, 'FRA': 233.8, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 222.0, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 10, 'G': 2, 'S': 5, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# AUS
# 1960
# 1960
# Updating time for AUS from 222.0 to 215.6
# FRA
# 1960
# 1960
# Updating time for FRA from 233.8 to 218.4
# 1960
# {'USA': 225.2, 'ALG': 100000, 'NZL': 227.8, 'KEN': 100000, 'FRA': 218.4, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 10, 'G': 2, 'S': 5, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# NZL
# 1964
# 1964
# Updating time for NZL from 227.8 to 218.1
# NZL
# 1964
# 1964
# 1964
# {'USA': 225.2, 'ALG': 100000, 'NZL': 218.1, 'KEN': 100000, 'FRA': 218.4, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 10, 'G': 2, 'S': 5, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# KEN
# 1968
# 1968
# Updating time for KEN from 100000 to 214.9
# USA
# 1968
# 1968
# Updating time for USA from 225.2 to 217.8
# 1968
# {'USA': 217.8, 'ALG': 100000, 'NZL': 218.1, 'KEN': 214.9, 'FRA': 218.4, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 233.2, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'KEN': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# FIN
# 1972
# 1972
# Updating time for FIN from 233.2 to 216.32999999999998
# KEN
# 1972
# 1972
# NZL
# 1972
# 1972
# Updating time for NZL from 218.1 to 217.46
# 1972
# {'USA': 217.8, 'ALG': 100000, 'NZL': 217.46, 'KEN': 214.9, 'FRA': 218.4, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 4, 'G': 2, 'S': 0, 'B': 2}, 'KEN': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# NZL
# 1976
# 1976
# 1976
# {'USA': 217.8, 'ALG': 100000, 'NZL': 217.46, 'KEN': 214.9, 'FRA': 218.4, 'MAR': 100000, 'ESP': 100000, 'GBR': 232.6, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 5, 'G': 3, 'S': 0, 'B': 2}, 'KEN': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 8, 'G': 3, 'S': 3, 'B': 2}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# GBR
# 1980
# 1980
# Updating time for GBR from 232.6 to 218.4
# GBR
# 1980
# 1980
# 1980
# {'USA': 217.8, 'ALG': 100000, 'NZL': 217.46, 'KEN': 214.9, 'FRA': 218.4, 'MAR': 100000, 'ESP': 100000, 'GBR': 218.4, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 5, 'G': 3, 'S': 0, 'B': 2}, 'KEN': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 10, 'G': 4, 'S': 3, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# GBR
# 1984
# 1984
# Updating time for GBR from 218.4 to 212.53
# GBR
# 1984
# 1984
# ESP
# 1984
# 1984
# Updating time for ESP from 100000 to 214.3
# 1984
# {'USA': 217.8, 'ALG': 100000, 'NZL': 217.46, 'KEN': 214.9, 'FRA': 218.4, 'MAR': 100000, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 5, 'G': 3, 'S': 0, 'B': 2}, 'KEN': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# 1988
# {'USA': 217.8, 'ALG': 100000, 'NZL': 217.46, 'KEN': 214.9, 'FRA': 218.4, 'MAR': 100000, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 5, 'G': 3, 'S': 0, 'B': 2}, 'KEN': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ESP': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# ESP
# 1992
# 1992
# MAR
# 1992
# 1992
# Updating time for MAR from 100000 to 220.62
# 1992
# {'USA': 217.8, 'ALG': 100000, 'NZL': 217.46, 'KEN': 214.9, 'FRA': 218.4, 'MAR': 220.62, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'NZL': {'total': 5, 'G': 3, 'S': 0, 'B': 2}, 'KEN': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'ESP': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# ALG
# 1996
# 1996
# Updating time for ALG from 100000 to 215.78
# ESP
# 1996
# 1996
# KEN
# 1996
# 1996
# 1996
# {'USA': 217.8, 'ALG': 215.78, 'NZL': 217.46, 'KEN': 214.9, 'FRA': 218.4, 'MAR': 220.62, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'NZL': {'total': 5, 'G': 3, 'S': 0, 'B': 2}, 'KEN': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'ESP': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# KEN
# 2000
# 2000
# Updating time for KEN from 214.9 to 212.07
# MAR
# 2000
# 2000
# Updating time for MAR from 220.62 to 212.32
# KEN
# 2000
# 2000
# 2000
# {'USA': 217.8, 'ALG': 215.78, 'NZL': 217.46, 'KEN': 212.07, 'FRA': 218.4, 'MAR': 212.32, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'NZL': {'total': 5, 'G': 3, 'S': 0, 'B': 2}, 'KEN': {'total': 5, 'G': 2, 'S': 1, 'B': 2}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 2, 'G': 0, 'S': 2, 'B': 0}, 'ESP': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# MAR
# 2004
# 2004
# KEN
# 2004
# 2004
# 2004
# {'USA': 217.8, 'ALG': 215.78, 'NZL': 217.46, 'KEN': 212.07, 'FRA': 218.4, 'MAR': 212.32, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'NZL': {'total': 5, 'G': 3, 'S': 0, 'B': 2}, 'KEN': {'total': 6, 'G': 2, 'S': 2, 'B': 2}, 'FRA': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'MAR': {'total': 3, 'G': 1, 'S': 2, 'B': 0}, 'ESP': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# KEN
# 2008
# 2008
# NZL
# 2008
# 2008
# Updating time for NZL from 217.46 to 214.16
# FRA
# 2008
# 2008
# Updating time for FRA from 218.4 to 214.21
# 2008
# {'USA': 217.8, 'ALG': 215.78, 'NZL': 214.16, 'KEN': 212.07, 'FRA': 214.21, 'MAR': 212.32, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 11, 'G': 2, 'S': 6, 'B': 3}, 'ALG': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'NZL': {'total': 6, 'G': 3, 'S': 1, 'B': 2}, 'KEN': {'total': 7, 'G': 3, 'S': 2, 'B': 2}, 'FRA': {'total': 5, 'G': 0, 'S': 3, 'B': 2}, 'MAR': {'total': 3, 'G': 1, 'S': 2, 'B': 0}, 'ESP': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# ALG
# 2012
# 2012
# Updating time for ALG from 215.78 to 214.07999999999998
# USA
# 2012
# 2012
# Updating time for USA from 217.8 to 214.79
# MAR
# 2012
# 2012
# 2012
# {'USA': 214.79, 'ALG': 214.07999999999998, 'NZL': 214.16, 'KEN': 212.07, 'FRA': 214.21, 'MAR': 212.32, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 12, 'G': 2, 'S': 7, 'B': 3}, 'ALG': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'NZL': {'total': 6, 'G': 3, 'S': 1, 'B': 2}, 'KEN': {'total': 7, 'G': 3, 'S': 2, 'B': 2}, 'FRA': {'total': 5, 'G': 0, 'S': 3, 'B': 2}, 'MAR': {'total': 4, 'G': 1, 'S': 2, 'B': 1}, 'ESP': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# USA
# 2016
# 2016
# ALG
# 2016
# 2016
# NZL
# 2016
# 2016
# 2016
# {'USA': 214.79, 'ALG': 214.07999999999998, 'NZL': 214.16, 'KEN': 212.07, 'FRA': 214.21, 'MAR': 212.32, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 13, 'G': 3, 'S': 7, 'B': 3}, 'ALG': {'total': 3, 'G': 2, 'S': 1, 'B': 0}, 'NZL': {'total': 7, 'G': 3, 'S': 1, 'B': 3}, 'KEN': {'total': 7, 'G': 3, 'S': 2, 'B': 2}, 'FRA': {'total': 5, 'G': 0, 'S': 3, 'B': 2}, 'MAR': {'total': 4, 'G': 1, 'S': 2, 'B': 1}, 'ESP': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}
# 2020
# {'USA': 214.79, 'ALG': 214.07999999999998, 'NZL': 214.16, 'KEN': 212.07, 'FRA': 214.21, 'MAR': 212.32, 'ESP': 214.3, 'GBR': 212.53, 'AUS': 215.6, 'LUX': 225.2, 'ITA': 229.2, 'FIN': 216.32999999999998, 'IRL': 221.2, 'SWE': 229.8}
# {'USA': {'total': 13, 'G': 3, 'S': 7, 'B': 3}, 'ALG': {'total': 3, 'G': 2, 'S': 1, 'B': 0}, 'NZL': {'total': 7, 'G': 3, 'S': 1, 'B': 3}, 'KEN': {'total': 7, 'G': 3, 'S': 2, 'B': 2}, 'FRA': {'total': 5, 'G': 0, 'S': 3, 'B': 2}, 'MAR': {'total': 4, 'G': 1, 'S': 2, 'B': 1}, 'ESP': {'total': 3, 'G': 1, 'S': 1, 'B': 1}, 'GBR': {'total': 12, 'G': 5, 'S': 4, 'B': 3}, 'AUS': {'total': 3, 'G': 2, 'S': 0, 'B': 1}, 'LUX': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'FIN': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'IRL': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'SWE': {'total': 2, 'G': 1, 'S': 1, 'B': 0}}

# %%
graph_data_women = []
best_times = {}
medal_counts = {}

for step in track_results_women:
    if step['country'] not in best_times:
        best_times[step['country']] = 100000
    if step['country'] not in medal_counts:
        medal_counts[step['country']] = {'total': 0, 'G': 0, 'S': 0, 'B': 0}

new_best_times = best_times.copy()
new_medals = medal_counts.copy()

for i in range(1896, 2021, 4):
    for entry in track_results_women:
        if entry['year'] == i:
            print(entry['country'])
            print(entry['year'])
            print(i)
            if entry['time'] == None:
                continue
            seconds = string_to_time(entry['time'])
            best_times = new_best_times.copy()
            new_best_times = update_best_times(best_times, entry['country'], seconds)
            medal_counts = new_medals.copy()
            new_medals = update_medal_count(medal_counts, entry['country'], entry['medal'], 1)

    print(i)
    print(best_times)
    print(medal_counts)
    graph_data_women.append({
        'year': i,
        'best_times': best_times,
        'medal_counts': medal_counts
    })


# Save the best times and medal counts to a json file
with open('./graph_data_women.json', 'w') as file:
    json.dump(graph_data_women, file, indent=4)
# Out:
# 1896
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1900
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1904
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1908
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1912
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1916
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1920
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1924
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1928
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1932
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1936
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1940
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1944
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1948
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1952
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1956
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1960
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1964
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1968
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 100000, 'URS': 100000, 'GDR': 100000, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'URS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GDR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# URS
# 1972
# 1972
# Updating time for URS from 100000 to 241.38
# GDR
# 1972
# 1972
# Updating time for GDR from 100000 to 242.83
# ITA
# 1972
# 1972
# Updating time for ITA from 100000 to 242.85
# 1972
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 242.85, 'URS': 241.38, 'GDR': 242.83, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'URS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'GDR': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# URS
# 1976
# 1976
# GDR
# 1976
# 1976
# GDR
# 1976
# 1976
# 1976
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 242.85, 'URS': 241.38, 'GDR': 242.83, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'URS': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'GDR': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# URS
# 1980
# 1980
# Updating time for URS from 241.38 to 236.6
# GDR
# 1980
# 1980
# Updating time for GDR from 242.83 to 237.8
# URS
# 1980
# 1980
# 1980
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 100000, 'EUN': 100000, 'CHN': 100000, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# ITA
# 1984
# 1984
# ROU
# 1984
# 1984
# Updating time for ROU from 100000 to 243.76
# ROU
# 1984
# 1984
# 1984
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 243.76, 'EUN': 100000, 'CHN': 100000, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# 1988
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 100000, 'ROU': 243.76, 'EUN': 100000, 'CHN': 100000, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ROU': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'EUN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'CHN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# ALG
# 1992
# 1992
# Updating time for ALG from 100000 to 235.3
# EUN
# 1992
# 1992
# Updating time for EUN from 100000 to 236.91
# CHN
# 1992
# 1992
# Updating time for CHN from 100000 to 237.07999999999998
# 1992
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 235.3, 'ROU': 243.76, 'EUN': 236.91, 'CHN': 237.07999999999998, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 100000, 'AUT': 100000}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ROU': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'EUN': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'CHN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'AUT': {'total': 0, 'G': 0, 'S': 0, 'B': 0}}
# RUS
# 1996
# 1996
# Updating time for RUS from 100000 to 240.83
# ROU
# 1996
# 1996
# Updating time for ROU from 243.76 to 241.54
# AUT
# 1996
# 1996
# Updating time for AUT from 100000 to 243.02
# 1996
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 235.3, 'ROU': 241.54, 'EUN': 236.91, 'CHN': 237.07999999999998, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 240.83, 'AUT': 243.02}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ROU': {'total': 3, 'G': 0, 'S': 2, 'B': 1}, 'EUN': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'CHN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'AUT': {'total': 1, 'G': 0, 'S': 0, 'B': 1}}
# ALG
# 2000
# 2000
# ROU
# 2000
# 2000
# ROU
# 2000
# 2000
# 2000
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 235.3, 'ROU': 241.54, 'EUN': 236.91, 'CHN': 237.07999999999998, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 100000, 'BRN': 100000, 'GBR': 100000, 'RUS': 240.83, 'AUT': 243.02}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'ROU': {'total': 5, 'G': 0, 'S': 3, 'B': 2}, 'EUN': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'CHN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'RUS': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'AUT': {'total': 1, 'G': 0, 'S': 0, 'B': 1}}
# GBR
# 2004
# 2004
# Updating time for GBR from 100000 to 237.9
# RUS
# 2004
# 2004
# Updating time for RUS from 240.83 to 238.12
# ROU
# 2004
# 2004
# Updating time for ROU from 241.54 to 238.39
# 2004
# {'KEN': 100000, 'ETH': 100000, 'USA': 100000, 'UKR': 100000, 'ALG': 235.3, 'ROU': 238.39, 'EUN': 236.91, 'CHN': 237.07999999999998, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 100000, 'BRN': 100000, 'GBR': 237.9, 'RUS': 238.12, 'AUT': 243.02}
# {'KEN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'ALG': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'ROU': {'total': 6, 'G': 0, 'S': 3, 'B': 3}, 'EUN': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'CHN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'RUS': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'AUT': {'total': 1, 'G': 0, 'S': 0, 'B': 1}}
# KEN
# 2008
# 2008
# Updating time for KEN from 100000 to 240.23
# UKR
# 2008
# 2008
# Updating time for UKR from 100000 to 241.63
# UKR
# 2008
# 2008
# 2008
# {'KEN': 240.23, 'ETH': 100000, 'USA': 100000, 'UKR': 241.63, 'ALG': 235.3, 'ROU': 238.39, 'EUN': 236.91, 'CHN': 237.07999999999998, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 100000, 'BRN': 100000, 'GBR': 237.9, 'RUS': 238.12, 'AUT': 243.02}
# {'KEN': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'ALG': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'ROU': {'total': 6, 'G': 0, 'S': 3, 'B': 3}, 'EUN': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'CHN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'BRN': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'GBR': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'RUS': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'AUT': {'total': 1, 'G': 0, 'S': 0, 'B': 1}}
# TUR
# 2012
# 2012
# Updating time for TUR from 100000 to 250.4
# BRN
# 2012
# 2012
# Updating time for BRN from 100000 to 250.74
# 2012
# {'KEN': 240.23, 'ETH': 100000, 'USA': 100000, 'UKR': 241.63, 'ALG': 235.3, 'ROU': 238.39, 'EUN': 236.91, 'CHN': 237.07999999999998, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 250.4, 'BRN': 250.74, 'GBR': 237.9, 'RUS': 238.12, 'AUT': 243.02}
# {'KEN': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'ETH': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'USA': {'total': 0, 'G': 0, 'S': 0, 'B': 0}, 'UKR': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'ALG': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'ROU': {'total': 6, 'G': 0, 'S': 3, 'B': 3}, 'EUN': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'CHN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'BRN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'GBR': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'RUS': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'AUT': {'total': 1, 'G': 0, 'S': 0, 'B': 1}}
# KEN
# 2016
# 2016
# ETH
# 2016
# 2016
# Updating time for ETH from 100000 to 250.27
# USA
# 2016
# 2016
# Updating time for USA from 100000 to 250.53
# 2016
# {'KEN': 240.23, 'ETH': 250.27, 'USA': 250.53, 'UKR': 241.63, 'ALG': 235.3, 'ROU': 238.39, 'EUN': 236.91, 'CHN': 237.07999999999998, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 250.4, 'BRN': 250.74, 'GBR': 237.9, 'RUS': 238.12, 'AUT': 243.02}
# {'KEN': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'ETH': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'USA': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'UKR': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'ALG': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'ROU': {'total': 6, 'G': 0, 'S': 3, 'B': 3}, 'EUN': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'CHN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'BRN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'GBR': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'RUS': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'AUT': {'total': 1, 'G': 0, 'S': 0, 'B': 1}}
# 2020
# {'KEN': 240.23, 'ETH': 250.27, 'USA': 250.53, 'UKR': 241.63, 'ALG': 235.3, 'ROU': 238.39, 'EUN': 236.91, 'CHN': 237.07999999999998, 'ITA': 242.85, 'URS': 236.6, 'GDR': 237.8, 'TUR': 250.4, 'BRN': 250.74, 'GBR': 237.9, 'RUS': 238.12, 'AUT': 243.02}
# {'KEN': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'ETH': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'USA': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'UKR': {'total': 2, 'G': 0, 'S': 1, 'B': 1}, 'ALG': {'total': 2, 'G': 2, 'S': 0, 'B': 0}, 'ROU': {'total': 6, 'G': 0, 'S': 3, 'B': 3}, 'EUN': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'CHN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'ITA': {'total': 2, 'G': 1, 'S': 0, 'B': 1}, 'URS': {'total': 4, 'G': 3, 'S': 0, 'B': 1}, 'GDR': {'total': 4, 'G': 0, 'S': 3, 'B': 1}, 'TUR': {'total': 1, 'G': 0, 'S': 1, 'B': 0}, 'BRN': {'total': 1, 'G': 0, 'S': 0, 'B': 1}, 'GBR': {'total': 1, 'G': 1, 'S': 0, 'B': 0}, 'RUS': {'total': 2, 'G': 1, 'S': 1, 'B': 0}, 'AUT': {'total': 1, 'G': 0, 'S': 0, 'B': 1}}

# %%
track_df_men = pd.DataFrame(track_results_men)
for i, time in enumerate(track_df_men['time']):
    if time == None:
        continue
    seconds = string_to_time(time)
    track_df_men.at[i, 'time'] = seconds

track_df_women = pd.DataFrame(track_results_women)
for i, time in enumerate(track_df_women['time']):
    if time == None:
        continue
    seconds = string_to_time(time)
    track_df_women.at[i, 'time'] = seconds

# sort values by ascending time
track_df_men.sort_values(by=['time'], inplace=True, ignore_index=True)
track_df_women.sort_values(by=['time'], inplace=True, ignore_index=True)

track_df_men.to_json('./best_times_results_men.json', orient='records')
track_df_women.to_json('./best_times_results_women.json', orient='records')
